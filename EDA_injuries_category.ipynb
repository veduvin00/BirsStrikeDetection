# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/Users/tenx/Desktop/Analytics Strategy (R)/Presentation/Fianl Presentation/STRIKE_REPORTS.xlsx")

# %%
counts = df["PHASE_OF_FLIGHT"].value_counts()

# %%
print(counts)
# Out:
# PHASE_OF_FLIGHT
# Approach        75224
# Landing Roll    32157
# Take-off Run    30248
# Climb           26957
# En Route         5308
# Departure        2933
# Descent          2331
# Local            1150
# Arrival           753
# Taxi              667
# Parked            115
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8, 5))
bars = ax.bar(counts.index, counts.values, color="#344966")

ax.bar_label(bars, padding=3)

ax.set_title("Category Frequency")
ax.set_xlabel("Category")
ax.set_ylabel("Number")
plt.xticks(rotation=45)  
plt.tight_layout()
plt.show()

# %%
injuries_by_phase = df.groupby("PHASE_OF_FLIGHT")["NR_INJURIES"].sum().sort_values(ascending=False)

# %%
print(injuries_by_phase)
# Out:
# PHASE_OF_FLIGHT
# En Route        160.0
# Approach         95.0
# Climb            37.0
# Take-off Run     36.0
# Landing Roll     23.0
# Local             3.0
# Descent           2.0
# Taxi              1.0
# Arrival           0.0
# Departure         0.0
# Parked            0.0
# Name: NR_INJURIES, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8,5))
bars = ax.bar(injuries_by_phase.index, injuries_by_phase.values, color="#344966")

ax.bar_label(bars)

ax.set_title("Total Injuries by Phase")
ax.set_xlabel("Phase")
ax.set_ylabel("Number of Injuries")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
